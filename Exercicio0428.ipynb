# %% [markdown]
# <a href="https://colab.research.google.com/github/Vitaminazz/MachineLearning_Icoma_Vitamina/blob/main/Exercicio0428.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd
import time

API_KEY = '5MIPGFL0S3ZJ3JIO'
SYMBOL = ['NFLX', 'AAPL', 'GOOGL','AMZN','MSFT']
lista_emp = []

for simbolo in EMPRESAS:
  print(f'Extraindo dados de {simbolo}')
  time.sleep(5)
  url = f'https://www.alphavantage.co/query?function=GLOBAL_QUOTE&symbol={simbolo}&apikey={API_KEY}'
  r = requests.get(url)
  base = r.json()

  if 'Global Quote' in base:
    temporario = pd.DataFrame([base['Global Quote']])
    lista_emp.append(temporario)

base_empresas = pd.concat(lista_emp)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1698/2212067951.py in <cell line: 0>()
#       7 lista_emp = []
#       8
# ----> 9 for simbolo in EMPRESAS:
#      10   print(f'Extraindo dados de {simbolo}')
#      11   time.sleep(5)
#
# NameError: name 'EMPRESAS' is not defined

# %%
base_empresas
# Out:
#   01. symbol 02. open 03. high  04. low 05. price 06. volume  \
# 0       NFLX  92.0500  92.8400  91.3000   91.3700   29707439
#
#   07. latest trading day 08. previous close 09. change 10. change percent
# 0             2026-04-27            92.4400    -1.0700           -1.1575%
